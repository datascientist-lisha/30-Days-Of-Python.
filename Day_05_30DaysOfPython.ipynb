# %% [markdown]
# # 30 Days of Python - Day 5: Lists
# Author: Asabeneh Yetayeh

# %% [markdown]
# ## Creating Lists

# %%
fruits = ['banana', 'orange', 'mango', 'lemon']
vegetables = ['Tomato', 'Potato', 'Cabbage', 'Onion', 'Carrot']
animal_products = ['milk', 'meat', 'butter', 'yoghurt']
web_techs = ['HTML', 'CSS', 'Bootstrap', 'JavaScript', 'React', 'Redux', 'Node', 'MongoDB']
countries = ['Finland', 'Estonia', 'Denmark', 'Sweden', 'Norway']
print('Fruits:', fruits)
print('Number of fruits:', len(fruits))
print('Vegetables:', vegetables)
print('Number of vegetables:', len(vegetables))

# %% [markdown]
# ## Accessing List Items

# %%
fruits = ['banana', 'orange', 'mango', 'lemon']
first_fruit = fruits[0]
print(first_fruit)
second_fruit = fruits[1]
print(second_fruit)
last_fruit = fruits[-1]
print(last_fruit)
last_index = len(fruits) - 1
last_fruit = fruits[last_index]
print(last_fruit)

# %% [markdown]
# ## Slicing Lists

# %%
fruits = ['banana', 'orange', 'mango', 'lemon']
all_fruits = fruits[0:4]
print(all_fruits)
orange_mango = fruits[1:3]
print(orange_mango)
orange_to_the_rest = fruits[1:]
print(orange_to_the_rest)

# %% [markdown]
# ## List Methods

# %%
fruits = ['banana', 'orange', 'mango', 'lemon']
fruits.append('apple')
print(fruits)
fruits.insert(2, 'watermelon')
print(fruits)
fruits.remove('banana')
print(fruits)
fruits.pop()
print(fruits)
fruits.sort()
print(fruits)
fruits.reverse()
print(fruits)

# %% [markdown]
# ## Exercises: Level 1

# %%
# 1. Declare an empty list
empty_list = []
print(empty_list)

# %%
# 2. Declare a list with more than 5 items
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
print(it_companies)
print(len(it_companies))

# %%
# 3. Find the length of your list
print(len(it_companies))

# %%
# 4. Get the first item, the middle item and the last item of the list
print(it_companies[0])
print(it_companies[len(it_companies)//2])
print(it_companies[-1])

# %%
# 5. Declare a list called mixed_data_types with different data types
mixed_data_types = ['Asabeneh', 250, True, {'country': 'Finland', 'city': 'Helsinki'}, [1, 2, 3, 4, 5]]
print(mixed_data_types)

# %% [markdown]
# ## Exercises: Level 2

# %%
# 1. Unpack first five countries and store in variables
countries = ['Finland', 'Sweden', 'Denmark', 'Norway', 'Iceland', 'Estonia', 'Russia']
fin, sw, den, nor, icel, *rest = countries
print(fin, sw, den, nor, icel)
print(rest)

# %%
# 2. Find the middle country in the countries list
countries = ['Finland', 'Sweden', 'Denmark', 'Norway', 'Iceland']
print(countries[len(countries)//2])

# %%
# 3. Divide the countries list into two equal lists
half = len(countries)//2
first_half = countries[:half]
second_half = countries[half:]
print(first_half)
print(second_half)

# %% [markdown]
# ## Exercises: Level 3

# %%
# 1. Remove the first item, the middle item and the last item
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
it_companies.pop(0)
it_companies.pop(len(it_companies)//2)
it_companies.pop()
print(it_companies)

# %%
# 2. Join the following lists
front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
back_end = ['Node', 'Express', 'MongoDB']
full_stack = front_end + back_end
print(full_stack)
