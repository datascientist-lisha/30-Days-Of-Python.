# %% [markdown]
# # 30 Days of Python - Day 26: Python Web
# Author: Asabeneh Yetayeh

# %% [markdown]
# ## Flask

# %%
flask_code = '''
from flask import Flask
app = Flask(__name__)

@app.route('/')
def home():
    return 'Hello, World!'

if __name__ == '__main__':
    app.run(debug=True)
'''
print(flask_code)

# %% [markdown]
# ## Exercises: Level 1

# %%
exercises = '''
1. Create a Flask app with / route returning Hello World
2. Add /about route returning About page
3. Add /contact route
'''
print(exercises)

# %% [markdown]
# ## Exercises: Level 2

# %%
exercises = '''
1. Add a 404 error handler
2. Create a /api route returning JSON
3. Add dynamic routing /user/<name>
'''
print(exercises)

# %% [markdown]
# ## Exercises: Level 3

# %%
print('See Asabeneh GitHub Day 26 for full exercises')
