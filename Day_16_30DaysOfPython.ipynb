# %% [markdown]
# # 30 Days of Python - Day 16: Python Datetime
# Author: Asabeneh Yetayeh

# %%
import datetime
print(dir(datetime))
print(datetime.datetime.now())
print(datetime.datetime.today())

# %% [markdown]
# ## Getting date and time information

# %%
from datetime import datetime
now = datetime.now()
print(now)
print(now.year)
print(now.month)
print(now.day)
print(now.hour)
print(now.minute)
print(now.second)
print(now.timestamp())
print(now.strftime('%m/%d/%Y, %H:%M:%S'))

# %% [markdown]
# ## Formatting Dates

# %%
from datetime import datetime
new_year = datetime(2020, 1, 1)
print(new_year)
day = new_year.day
month = new_year.month
year = new_year.year
hour = new_year.hour
minute = new_year.minute
second = new_year.second
print(day, month, year, hour, minute)
print(f'{day}/{month}/{year}, {hour}:{minute}')

# %% [markdown]
# ## timedelta

# %%
from datetime import datetime, timedelta
t1 = datetime(year=2019, month=12, day=5, hour=0, minute=59, second=0)
t2 = datetime(year=2020, month=1, day=1, hour=0, minute=0, second=0)
delta = t2 - t1
print(delta)
print(delta.days)
print(delta.total_seconds())

# %% [markdown]
# ## Exercises: Level 1

# %%
# 1. Get the current day, month, year, hour, minute and second from datetime module
from datetime import datetime
now = datetime.now()
print('Year:', now.year)
print('Month:', now.month)
print('Day:', now.day)
print('Hour:', now.hour)
print('Minute:', now.minute)
print('Second:', now.second)

# %%
# 2. Format the current date as %m/%d/%Y/%H:%M:%S
print(now.strftime('%m/%d/%Y/%H:%M:%S'))

# %%
# 3. Today is 5 December, 2019. Change this time string to time
date_string = 'December 5, 2019'
date_object = datetime.strptime(date_string, '%B %d, %Y')
print(date_object)

# %% [markdown]
# ## Exercises: Level 2

# %%
# 1. Calculate the age of a person from date of birth
from datetime import date
date_of_birth = date(1990, 1, 1)
today = date.today()
age = today.year - date_of_birth.year
if (today.month, today.day) < (date_of_birth.month, date_of_birth.day):
    age -= 1
print('Age:', age)

# %%
# 2. Calculate number of days between two dates
from datetime import date
date1 = date(2021, 1, 1)
date2 = date(2024, 1, 1)
delta = date2 - date1
print('Days between:', delta.days)

# %% [markdown]
# ## Exercises: Level 3

# %%
# 1. Format the time output
from datetime import datetime
now = datetime.now()
formats = ['%Y-%m-%d', '%d-%m-%Y', '%m/%d/%Y', '%B %d, %Y', '%d %B, %Y',
           '%A, %B %d, %Y', '%I:%M %p']
for fmt in formats:
    print(now.strftime(fmt))
