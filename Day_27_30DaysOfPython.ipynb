# %% [markdown]
# # 30 Days of Python - Day 27: Python with MongoDB
# Author: Asabeneh Yetayeh

# %% [markdown]
# ## Installing PyMongo

# %%
# pip install pymongo
print('MongoDB Python driver installation command shown above')

# %% [markdown]
# ## Connecting to MongoDB

# %%
mongo_code = '''
import pymongo
client = pymongo.MongoClient('mongodb://localhost:27017/')
db = client['thirty_days_of_python']
'''
print(mongo_code)

# %% [markdown]
# ## CRUD Operations

# %%
crud = '''
collection.insert_one({'name': 'Asabeneh'})
collection.insert_many([{'name': 'David'}, {'name': 'John'}])
collection.find()
collection.find_one({'name': 'Asabeneh'})
collection.update_one({'name': 'Asabeneh'}, {'$set': {'age': 250}})
collection.delete_one({'name': 'Asabeneh'})
'''
print(crud)

# %% [markdown]
# ## Exercises

# %%
print('See Asabeneh GitHub Day 27 for full exercises')
