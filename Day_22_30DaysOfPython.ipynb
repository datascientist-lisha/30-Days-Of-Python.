# %% [markdown]
# # 30 Days of Python - Day 22: Web Scraping
# Author: Asabeneh Yetayeh

# %% [markdown]
# ## Installing Packages

# %%
# pip install requests
# pip install beautifulsoup4
import requests
from bs4 import BeautifulSoup
print('Libraries ready')

# %% [markdown]
# ## Scraping a Website

# %%
url = 'http://www.etherscan.io'
try:
    response = requests.get(url)
    status = response.status_code
    print('Status:', status)
except Exception as e:
    print(e)

# %% [markdown]
# ## Exercises: Level 1

# %%
# 1. Scrape the following website and store the data as json file
# url = 'http://www.pythonscraping.com/'
# Use BeautifulSoup to extract headings, paragraphs, links
print('Web scraping exercise - see Asabeneh GitHub for full exercise details')

# %% [markdown]
# ## Exercises: Level 2

# %%
# 1. Scrape the table from https://www.worldometers.info/world-population/world-population-by-country/
# Store country, population, area as json
print('See Asabeneh GitHub Day 22 for full exercise details')

# %% [markdown]
# ## Exercises: Level 3

# %%
# 1. Extract the table from the above url into a pandas dataframe
print('See Asabeneh GitHub Day 22 for full exercise details')
