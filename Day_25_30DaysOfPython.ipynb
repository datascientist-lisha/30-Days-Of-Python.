# %% [markdown]
# # 30 Days of Python - Day 25: Pandas
# Author: Asabeneh Yetayeh

# %% [markdown]
# ## Importing Pandas

# %%
import pandas as pd
import numpy as np
print(pd.__version__)

# %% [markdown]
# ## Creating DataFrames

# %%
data = {
    'Name': ['Asabeneh', 'David', 'John'],
    'Country': ['Finland', 'UK', 'USA'],
    'City': ['Helsinki', 'London', 'NY']
}
df = pd.DataFrame(data)
print(df)

# %% [markdown]
# ## Reading Files

# %%
# df = pd.read_csv('data.csv')
# df = pd.read_excel('data.xlsx')
# df = pd.read_json('data.json')
print('Common pandas reading methods shown above')

# %% [markdown]
# ## Exercises: Level 1

# %%
df = pd.DataFrame({'A': [1,2,3], 'B': [4,5,6]})
print(df.head())
print(df.info())
print(df.describe())

# %% [markdown]
# ## Exercises: Level 2

# %%
import pandas as pd
df = pd.DataFrame({'score': [85,90,72,65,88,95,100,55]})
print('Mean:', df['score'].mean())
print('Median:', df['score'].median())
print('Std:', df['score'].std())

# %% [markdown]
# ## Exercises: Level 3

# %%
# Explore the weight-height dataset
# Read from: https://raw.githubusercontent.com/Asabeneh/30-Days-Of-Python/master/data/weight_height.csv
print('See Asabeneh GitHub Day 25 for dataset and full exercises')
