# %% [markdown]
# # 30 Days of Python - Day 4: Strings
# Author: Asabeneh Yetayeh

# %% [markdown]
# ## Creating Strings

# %%
letter = 'P'
print(letter)
print(len(letter))
greeting = 'Hello, World!'
print(greeting)
print(len(greeting))
sentence = "I hope you are enjoying 30 days of Python Challenge"
print(sentence)

# %% [markdown]
# ## String Concatenation

# %%
first_name = 'Asabeneh'
last_name = 'Yetayeh'
space = ' '
full_name = first_name + space + last_name
print(full_name)
print(len(full_name))

# %% [markdown]
# ## Escape Sequences

# %%
print('I hope everyone is enjoying the Python Challenge.
Are you ?')
print('Days	Topics	Exercises')
print('Day 1	3	5')
print('Day 2	3	5')
print('Day 3	3	5')
print('Day 4	3	5')
print('This is a backslash  symbol (\\)')
print('In every programming language it starts with "Hello, World!"')

# %% [markdown]
# ## String Formatting

# %%
radius = 10
pi = 3.14159
area = pi * radius ** 2
print('The area of a circle with radius {} is {:.2f}.'.format(radius, area))
print(f'The area of a circle with radius {radius} is {area:.2f}.')

# %% [markdown]
# ## String Methods

# %%
challenge = 'thirty days of python'
print(challenge.upper())
print(challenge.lower())
print(challenge.title())
print(challenge.swapcase())
print(challenge.capitalize())

# %%
print(challenge.count('y'))
print(challenge.find('y'))
print(challenge.rfind('y'))
print(challenge.replace('python', 'coding'))
print(challenge.split())
print(challenge.strip())
print(challenge.startswith('thirty'))
print(challenge.endswith('python'))

# %% [markdown]
# ## Exercises: Level 1

# %%
# 1. Concatenate 'Thirty', 'Days', 'Of', 'Python' to a single string '30 Days Of Python'
string = 'Thirty' + ' ' + 'Days' + ' ' + 'Of' + ' ' + 'Python'
print(string)

# %%
# 2. Concatenate 'Coding', 'For', 'All' to a single string 'Coding For All'
string = 'Coding' + ' ' + 'For' + ' ' + 'All'
print(string)

# %%
# 3. Declare a variable company and assign it to 'Coding For All'
company = 'Coding For All'
print(company)
print(len(company))

# %%
# 4. Change the string to uppercase and lowercase
print(company.upper())
print(company.lower())

# %%
# 5. Use slice or find to get the first word of the string
print(company[0:6])
print(company.split()[0])

# %%
# 6. Check if the string contains a word 'Coding'
print('Coding' in company)

# %% [markdown]
# ## Exercises: Level 2

# %%
# 1. Find the number of occurrences of the word because in the sentence
sentence = 'You cannot end a sentence with because because because is a conjunction'
print(sentence.count('because'))

# %%
# 2. Clean the following sentence
sentence2 = ' Coding For All '
print(sentence2.strip())

# %%
# 3. Use startswith() on the following string
print('Coding For All'.startswith('Coding'))

# %% [markdown]
# ## Exercises: Level 3

# %%
# 1. 'Love is the best thing in this world. Some found their love and some are still looking for their love.'
# Count the number of word love in this sentence
sentence = 'Love is the best thing in this world. Some found their love and some are still looking for their love.'
print(sentence.lower().count('love'))

# %%
# 2. Use sum, min and max to find sum, min and max
numbers = [1, 2, 3, 4, 5]
print('Sum:', sum(numbers))
print('Min:', min(numbers))
print('Max:', max(numbers))
