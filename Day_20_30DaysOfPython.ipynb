# %% [markdown]
# # 30 Days of Python - Day 20: Python Package Manager
# Author: Asabeneh Yetayeh

# %% [markdown]
# ## pip

# %%
# Check pip version
import subprocess
result = subprocess.run(['pip', '--version'], capture_output=True, text=True)
print(result.stdout)

# %%
# List installed packages
result = subprocess.run(['pip', 'list'], capture_output=True, text=True)
print(result.stdout[:2000])

# %% [markdown]
# ## Installing Packages

# %%
# Common pip commands
commands = '''
pip install package_name
pip install package_name==version
pip install -r requirements.txt
pip uninstall package_name
pip list
pip show package_name
pip freeze > requirements.txt
pip install --upgrade package_name
'''
print(commands)

# %% [markdown]
# ## Virtual Environment

# %%
venv_steps = '''
Steps to create a virtual environment:
1. python -m venv venv
2. Activate:
   Mac/Linux: source venv/bin/activate
   Windows:   venv\Scripts\activate
3. Install packages
4. pip freeze > requirements.txt
5. deactivate
'''
print(venv_steps)

# %% [markdown]
# ## Exercises: Level 1

# %%
# 1. Check if you have installed pip
import subprocess
result = subprocess.run(['pip', '--version'], capture_output=True, text=True)
print(result.stdout)

# %%
# 2. Check if you have installed numpy, pandas, requests, flask
packages = ['numpy', 'pandas', 'requests', 'flask']
for pkg in packages:
    try:
        __import__(pkg)
        print(f'{pkg}: installed')
    except ImportError:
        print(f'{pkg}: NOT installed')

# %% [markdown]
# ## Exercises: Level 2

# %%
# 1. Import numpy, matplotlib, pandas and check their versions
import numpy as np
import matplotlib
import pandas as pd

print('numpy:', np.__version__)
print('matplotlib:', matplotlib.__version__)
print('pandas:', pd.__version__)

# %% [markdown]
# ## Exercises: Level 3

# %%
# 1. Try these packages and describe what they are used for
packages_info = {
    'numpy': 'numerical computing, arrays, mathematics',
    'pandas': 'data analysis and manipulation',
    'matplotlib': 'data visualization and plotting',
    'requests': 'HTTP requests, consuming APIs',
    'flask': 'lightweight web framework',
    'sqlalchemy': 'SQL database toolkit and ORM',
    'scipy': 'scientific computing',
    'scikit-learn': 'machine learning',
    'pillow': 'image processing',
    'beautifulsoup4': 'web scraping'
}
for pkg, info in packages_info.items():
    print(f'{pkg}: {info}')
